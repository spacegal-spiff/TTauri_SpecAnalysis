# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
from astropy.io import fits
import glob
from astropy import units as u
from astropy import constants as const
import time
from dust_extinction.parameter_averages import F99
import pyspeckit as p
from EqW import *
from spec_modelfit import *

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wv, fl, flerr = np.loadtxt('./Extinction/V410/Reduced_Oct/meduv.txt', unpack=True)

# %%
figure = plt.figure(figsize = (20, 8))
plt.plot(wv, fl)
plt.ylim(0,0.5e-15)
# Out:
# (0, 5e-16)

# %%
# Look at just the Ca I 4227 Å line:
figure = plt.figure(figsize = (20, 8))
plt.plot(wv, fl)
plt.ylim(-1e-16,4e-16)
plt.xlim(410,440)
plt.vlines(422.7, -1e-16, 4e-16)

# %%
measure_equivalent_width(fl, flerr, wv, 419, 426, 421, 424, 100)
# Out:
# WARNING: No header given.  Creating an empty one.
# WARNING: 'units' is deprecated; please use 'unit' [pyspeckit.spectrum.units]
# ...
# INFO: Renormalizing data by factor 6.793591e-17 to improve fitting procedure [pyspeckit.spectrum.fitters]
# ...
# INFO: Renormalizing data by factor 7.290088e-17 to improve fitting procedure [pyspeckit.spectrum.fitters]
# 1.352112890235226
# INFO: Renormalizing data by factor 7.204763e-17 to improve fitting procedure [pyspeckit.spectrum.fitters]
# 1.3744394750130198
# INFO: Renormalizing data by factor 7.268618e-17 to improve fitting procedure [pyspeckit.spectrum.fitters]
# 1.1904321828791828
# INFO: Renormalizing data by factor 7.237835e-17 to improve fitting procedure [pyspeckit.spectrum.fitters]
# 1.263614142397498
# INFO: Renormalizing data by factor 7.149793e-17 to improve fitting procedure [pyspeckit.spectrum.fitters]
# ...
# 1.2017325703795032
# INFO: Renormalizing data by factor 7.152034e-17 to improve fitting procedure [pyspeckit.spectrum.fitters]
# ...

# %%
# Look naively at the balmer jump region:
figure = plt.figure(figsize = (20, 8))
plt.plot(wv, fl)
plt.ylim(-1e-16,4e-16)
plt.xlim(330,400)
plt.vlines(364., -1e-16, 4e-16)

# %%
# test rebin
from astropy.convolution import convolve, Box1DKernel

# %%
smoothed_signal = convolve(fl, Box1DKernel(10))

# %%
# maybe if we rebinned it...?
figure = plt.figure(figsize = (20, 8))
plt.plot(wv, smoothed_signal)
plt.ylim(-1e-16,4e-16)
plt.xlim(330,400)
plt.vlines(364., -1e-16, 4e-16)
